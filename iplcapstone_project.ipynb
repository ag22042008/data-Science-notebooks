# %% [markdown]
# <a href="https://colab.research.google.com/github/ag22042008/data-Science-notebooks/blob/main/iplcapstone_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# loading

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('/content/IPL.csv')

# %%
# basic information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
# check size of dataset
print(f'Your rows are {df.shape[0]} and your columns are {df.shape[1]}')
# Out:
# your rows are 74 and your columns are 20

# %% [markdown]
# Now let's see how many columns have null values in total.

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
match_wins=df['match_winner'].value_counts()

# %%
sns.barplot(y=match_wins.index,x=match_wins.values,color='red',palette='viridis')
plt.title('Most Match wins by team')
# Out:
# Text(0.5, 1.0, 'Most Match wins by team')

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df.tail()
# Out:
#     match_id         date                             venue      team1  \
# 69        70  May 22,2022          Wankhede Stadium, Mumbai  Hyderabad
# 70        71  May 24,2022             Eden Gardens, Kolkata    Gujarat
# 71        72  May 25,2022             Eden Gardens, Kolkata   Banglore
# 72        73  May 27,2022  Narendra Modi Stadium, Ahmedabad   Banglore
# 73        74  May 29,2022  Narendra Modi Stadium, Ahmedabad    Gujarat
#
#         team2    stage toss_winner toss_decision  first_ings_score  \
# 69     Punjab    Group   Hyderabad           Bat               157
# 70  Rajasthan  Playoff     Gujarat         Field               188
# 71    Lucknow  Playoff     Lucknow         Field               207
# 72  Rajasthan  Playoff   Rajasthan         Field               157
# 73  Rajasthan    Final   Rajasthan           Bat               130
#
#     first_ings_wkts  second_ings_score  second_ings_wkts match_winner  \
# ...

# %% [markdown]
# #2 toss descision trends

# %%
sns.countplot(x=df['toss_decision'],palette='viridis')
# Out:
# <Axes: xlabel='toss_decision', ylabel='count'>

# %% [markdown]
# #3 TOSS WINNER VS MATCH WINNER

# %%
# WE HAVE TO ANALYZE NOT VISUALIZE SOMETHING
df[df['toss_winner']==df['match_winner']]
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 5          6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
# 6          7  March 31,2022                     Brabourne Stadium, Mumbai
# 7          8   April 1,2022                      Wankhede Stadium, Mumbai
# 12        13   April 5,2022                      Wankhede Stadium, Mumbai
# 13        14   April 6,2022  Maharashtra Cricket Association Stadium,Pune
# 14        15   April 7,2022            Dr DY Patil Sports Academy, Mumbai
# 15        16   April 8,2022                     Brabourne Stadium, Mumbai
# 16        17   April 9,2022            Dr DY Patil Sports Academy, Mumbai
# ...

# %%
df[df['toss_winner']==df['match_winner']]['match_id'].count()
# Out:
# np.int64(36)

# %%
PERCENTAGE=(df[df['toss_winner']==df['match_winner']]['match_id'].count()*100)/df.shape[0]

# %%
PERCENTAGE
# Out:
# np.float64(48.648648648648646)

# %%
PERCENTAGE.round(2)
# Out:
# np.float64(48.65)

# %% [markdown]
# How do teams win? (Runs vs Wickets)

# %%
sns.countplot(x=df['won_by'],palette='viridis')
plt.title('Teams Win by runs or wickets')
# Out:
# Text(0.5, 1.0, 'Teams Win by runs or wickets')

# %% [markdown]
# #key player performances
# 1 Most "Player of the Match" Awards

# %%
count=df['player_of_the_match'].value_counts()

# %%
count1=count.head(10)

# %%
count1
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Wanindu Hasaranga    2
# Umesh Yadav          2
# Quinton de Kock      2
# Shubman Gill         2
# Avesh Khan           2
# Dinesh Karthik       2
# Hardik Pandya        2
# Rahul Tripathi       2
# Name: count, dtype: int64

# %%
sns.barplot(y=count1.index,x=count1.values,palette='rainbow')
plt.title('Most Player of the Match Awards')
# Out:
# Text(0.5, 1.0, 'Most Player of the Match Awards')

# %% [markdown]
# # top scorer in each match

# %%
# if we want to work with 2 different  columns we have to group on basis of 1 column and then perform on 2nd column

# %%
high=df.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(5) # is an aggregate

# %%
high.plot(kind='barh')
# Out:
# <Axes: ylabel='top_scorer'>

# %% [markdown]
# # best bowling figures

# %%
# extract wickets of best bowling figure
df['highest_wickets']=df['best_bowling_figure'].apply(lambda x :x.split('--')[0])
df['highest_wickets']=df['highest_wickets'].astype(int)

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# ...

# %%
top_bowlers=df.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)

# %%
top_bowlers
# Out:
# best_bowling
# Yuzvendra Chahal     17
# Jasprit Bumrah       11
# Kuldeep Yadav        11
# Rashid Khan          11
# Josh Hazlewood       10
# Kagiso Rabada        10
# Avesh Khan           10
# Umran Malik           9
# Wanindu Hasaranga     9
# T Natarajan           8
# Name: highest_wickets, dtype: int64

# %%
sns.barplot(y=top_bowlers.index,x=top_bowlers.values,palette='rainbow')
# Out:
# <Axes: ylabel='best_bowling'>

# %% [markdown]
# venue (most match played)

# %%
venue_count=df['venue'].value_counts()

# %%
sns.barplot(y=venue_count.index,x=venue_count.values,palette='rainbow')
# Out:
# <Axes: ylabel='venue'>

# %% [markdown]
# who won the highest margin by runs

# %%
df[df['won_by'] == 'Runs'].sort_values(by = 'margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %% [markdown]
# which player has highest score

# %%
df[df['highscore']==df['highscore'].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %%
# best bowling figures
df[df['highest_wickets']==df['highest_wickets'].max()][['best_bowling','best_bowling_figure']]
# Out:
#          best_bowling best_bowling_figure
# 29   Yuzvendra Chahal               5--40
# 39        Umran Malik               5--25
# 53  Wanindu Hasaranga               5--18
# 55     Jasprit Bumrah               5--10
