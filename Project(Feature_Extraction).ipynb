# %% [markdown]
# <a href="https://colab.research.google.com/github/ag22042008/data-Science-notebooks/blob/main/Project(Feature_Extraction).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/anime.csv')

# %%
df
# Out:
#     Rank                                              Title  Score
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
df.head()
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %%
#feature extraction - koi jo title diya ho usse jo features extract ho ske like episode count krenge hm jo inbuilt hsi title ke andar

# %%
df.loc[7]['Title']
# Out:
# 'Hunter x Hunter TV (148 eps)Oct 2011 - Sep 20142,701,154 members'

# %%
def extract_features(text):
  g="";
  d=False;
  for i in text:
    if(i==')'):
      d=False
      return g;
    if(i=='('):
      d=True;
    if(d and i!='('):
     g+=i;

# %%
df['Episode Count']=df['Title'].apply(extract_features)

# %%
df['Episode Count']=df['Episode Count'].str.replace('eps',' ')

# %%
df
# Out:
#     Rank                                              Title  Score  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
df['Episode Count']=df['Episode Count'].astype(int)# type conversions

# %%
df
# Out:
#     Rank                                              Title  Score  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           50 non-null     int64
#  1   Title          50 non-null     object
#  2   Score          50 non-null     float64
#  3   Episode Count  50 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.7+ KB

# %%
df.loc[0]['Title']
# Out:
# 'Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview'

# %%
def extract_time(text):
  check=False;
  data=""
  for i in range(len(text)):
    if text[i]==')':
      for j in range (i+1,i+20):
        data+=text[j];

      return data;

# %%
df['Total_Time']=df['Title'].apply(extract_time)

# %%
df
# Out:
#     Rank                                              Title  Score  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
df[df['Score']==df['Score'].max()]['Title']
# Out:
# 0    Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# Name: Title, dtype: object

# %%
#make a new column for episode count
#make a new column for time stamp
#which anime has the highest score
#give me top 5 highest scoring anime
#which anime has the highest episode count
#animes with top 5 episode count
#which is the longest running anime

# %%
df['Score'].head()
# Out:
# 0    9.10
# 1    9.07
# 2    9.06
# 3    9.06
# 4    9.05
# Name: Score, dtype: float64

# %%
from dateutil.relativedelta import relativedelta
from datetime import datetime

def calculate_total_months(period):
    try:
        start_str, end_str = period.split(' - ')
        start_date = datetime.strptime(start_str, '%b %Y')
        end_date = datetime.strptime(end_str, '%b %Y')
        r = relativedelta(end_date, start_date)
        return r.years * 12 + r.months + 1  # +1 to include the starting month
    except:
        return None

df['Months'] = df['TimeStamp'].apply(calculate_total_months)

# %%
df
# Out:
#     Rank                                              Title  Score  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
print(df['Score'].value_counts)# What it does:
#What it does:
#Gives all different (distinct) values in a column.

#Example:

#df["scores"].unique()


#Output idea:

#[10, 20, 30, 40]


#Use when:
#👉 You want to see what values exist, not how many times.

##✅ value_counts()

#What it does:
#Counts how many times each value appears.#
# Out:
# <bound method IndexOpsMixin.value_counts of 0     9.10
# 1     9.07
# 2     9.06
# 3     9.06
# 4     9.05
# 5     9.04
# 6     9.04
# 7     9.04
# 8     9.04
# 9     9.03
# 10    9.03
# 11    9.02
# 12    8.99
# 13    8.99
# 14    8.98
# 15    8.94
# 16    8.94
# 17    8.93
# 18    8.93
# 19    8.91
# 20    8.91
# 21    8.89
# 22    8.88
# 23    8.88
# 24    8.87
# 25    8.84
# 26    8.84
# 27    8.83
# 28    8.83
# 29    8.82
# 30    8.82
# 31    8.81
# 32    8.81
# 33    8.80
# 34    8.80
# 35    8.79
# 36    8.79
# 37    8.79
# 38    8.78
# 39    8.78
# 40    8.77
# 41    8.77
# 42    8.76
# 43    8.75
# 44    8.75
# 45    8.74
# 46    8.73
# 47    8.72
# 48    8.71
# 49    8.71
# Name: Score, dtype: float64>

# %%
print(df['Score'].unique)
# Out:
# <bound method Series.unique of 0     9.10
# 1     9.07
# 2     9.06
# 3     9.06
# 4     9.05
# 5     9.04
# 6     9.04
# 7     9.04
# 8     9.04
# 9     9.03
# 10    9.03
# 11    9.02
# 12    8.99
# 13    8.99
# 14    8.98
# 15    8.94
# 16    8.94
# 17    8.93
# 18    8.93
# 19    8.91
# 20    8.91
# 21    8.89
# 22    8.88
# 23    8.88
# 24    8.87
# 25    8.84
# 26    8.84
# 27    8.83
# 28    8.83
# 29    8.82
# 30    8.82
# 31    8.81
# 32    8.81
# 33    8.80
# 34    8.80
# 35    8.79
# 36    8.79
# 37    8.79
# 38    8.78
# 39    8.78
# 40    8.77
# 41    8.77
# 42    8.76
# 43    8.75
# 44    8.75
# 45    8.74
# 46    8.73
# 47    8.72
# 48    8.71
# 49    8.71
# Name: Score, dtype: float64>

# %%
df[df['Episode Count']==df['Episode Count'].max()]
# Out:
#     Rank                                              Title  Score  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94
#
#     Episode Count            TimeStamp  Months
# 15            201  Apr 2006 - Mar 2010      48

# %%
df['Episode Count'].head()
# Out:
# 0    64
# 1    24
# 2    13
# 3    51
# 4    10
# Name: Episode Count, dtype: int64

# %%
# highest values of scores top5
df.sort_values('Episode Count',ascending=False).head()
# Out:
#     Rank                                              Title  Score  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 42    43  Hajime no IppoTV (75 eps)Oct 2000 - Mar 200255...   8.76
# 24    25  MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...   8.87
#
#     Episode Count            TimeStamp  Months
# 15            201  Apr 2006 - Mar 2010      48
# 7             148  Oct 2011 - Sep 2014      36
# 11            110  Jan 1988 - Mar 1997     111
# 42             75  Oct 2000 - Mar 2002      18
# 24             74  Apr 2004 - Sep 2005      18

# %%
# longest running annime
df[df['Months']==df['Months'].max()]['Title']
# Out:
# 11    Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...
# Name: Title, dtype: object
