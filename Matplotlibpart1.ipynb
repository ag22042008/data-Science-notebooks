# %% [markdown]
# <a href="https://colab.research.google.com/github/ag22042008/data-Science-notebooks/blob/main/Matplotlibpart1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)
x
y=x**3

# %%
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y)
plt.title('matplotlib ')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
# subplots in matplotlib
#ek sath ap multiple plots bnana cha rhe ho
# if we choose like subplot(2,2) we divide our canvas in 2 rows and2 columns and if we want to select any box just
# need to tell(2,2,1)for 1 box 2,2,2 for 2 like this for creating various plots on a single canvas

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt .plot(y,x)
plt.subplot(2,2,3)
plt.plot(x,x**2)
plt.subplot(2,2,4)
plt.plot(x,x**3)

# %%
# now for creating plots in these subplots
# select
plt.subplot(2,2,1)
plt.plot(x,y)

# %% [markdown]
# # object oriented way
# # this a way to represent  or plot an axis in fully canvas or control the canvas fully in our way
# Object Oriented way
#
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch).

# %%
fig=plt.figure(figsize=[6,8],dpi=200)#[6,8]->600*800(width*height) for we can perform changes in fig size and dpi fig obj is created
fig.set_facecolor('lightgray')
axis1=fig.add_axes([0.1,0.5,0.9,0.7])# 1->left se distance 2->bottom se distance 3-> width 4-> height
axis1.plot(x,x**2,color='lightblue')# axis pr hi plot kr skte h

axis2=fig.add_axes([0.2,0.7,0.6,0.4])
axis2.plot(x,x**3)

# %%
# types of plots

# %%
plt.scatter(x,y)

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data)#weonly need to work with x y will automatically be generated
# Out:
# (array([ 8.,  6., 14.,  8.,  9., 13., 13., 12., 10.,  7.]),
#  array([ 21. , 118.7, 216.4, 314.1, 411.8, 509.5, 607.2, 704.9, 802.6,
#         900.3, 998. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x77fc36dcc3b0>,
#   <matplotlib.lines.Line2D at 0x77fc36dcc6b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x77fc36dcc980>,
#   <matplotlib.lines.Line2D at 0x77fc36dccc80>],
#  'boxes': [<matplotlib.lines.Line2D at 0x77fc36b2cbc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x77fc36dccf80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x77fc36dcd1f0>],
#  'means': []}

# %%
# saving the plots
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig('my_plot.png')

# %%
#working with images
import matplotlib.image as mpimg

# %%
img=mpimg.imread('/content/images.jpeg')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(451.5), np.float64(677.5), np.float64(-0.5))

# %%
img
# Out:
# array([[[ 91,  91,  93],
#         [ 91,  91,  93],
#         [ 91,  91,  93],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        [[ 91,  91,  93],
#         [ 91,  91,  93],
#         [ 91,  91,  93],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        [[ 91,  91,  93],
#         [ 91,  91,  93],
#         [ 91,  91,  93],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        ...,
#
#        [[245, 253, 255],
#         [245, 253, 255],
#         [245, 253, 255],
#         ...,
#         [153, 153, 153],
#         [153, 153, 153],
#         [153, 153, 153]],
#
#        [[245, 253, 255],
#         [245, 253, 255],
#         [245, 253, 255],
#         ...,
#         [153, 153, 153],
#         [153, 153, 153],
#         [153, 153, 153]],
#
#        [[245, 253, 255],
#         [245, 253, 255],
#         [245, 253, 255],
#         ...,
#         [153, 153, 153],
#         [153, 153, 153],
#         [153, 153, 153]]], dtype=uint8)

# %%
cropped_img=img[400:500,100:300]
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(99.5), np.float64(-0.5))

# %%
cropped_img
# Out:
# array([[[164, 120,  91],
#         [160, 119,  89],
#         [157, 116,  86],
#         ...,
#         [146, 146, 146],
#         [147, 147, 147],
#         [147, 147, 147]],
#
#        [[165, 122,  90],
#         [162, 119,  87],
#         [160, 117,  85],
#         ...,
#         [146, 146, 146],
#         [147, 147, 147],
#         [147, 147, 147]],
#
#        [[166, 123,  91],
#         [164, 121,  89],
#         [162, 119,  87],
#         ...,
#         [146, 146, 146],
#         [147, 147, 147],
#         [147, 147, 147]],
#
#        ...,
#
#        [[242, 245, 250],
#         [243, 246, 251],
#         [244, 247, 252],
#         ...,
#         [145, 145, 145],
#         [145, 145, 145],
#         [145, 145, 145]],
#
#        [[242, 245, 250],
#         [242, 245, 250],
#         [243, 246, 251],
#         ...,
#         [145, 145, 145],
#         [145, 145, 145],
#         [145, 145, 145]],
#
#        [[241, 244, 249],
#         [241, 244, 249],
#         [242, 245, 250],
#         ...,
#         [145, 145, 145],
#         [145, 145, 145],
#         [145, 145, 145]]], dtype=uint8)

# %%
#optional designing
plt.plot(x,y,color='red')

# %%
# some more designing stuff
xaxis=np.linspace(0,5,10)
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8,
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
